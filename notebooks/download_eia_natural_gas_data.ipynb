# %%
import sys
from pathlib import Path

current_dir = Path.cwd()
sys.path.append(str(current_dir.parent))

from src import download_henryhub_raw

download_henryhub_raw.download_henryhub_html()
download_henryhub_raw.download_eia_csv("T01.11", "EIA_T01_11_HDD_by_CensusDivision.csv")
download_henryhub_raw.download_eia_csv("T01.12", "EIA_T01_12_CDD_by_CensusDivision.csv")
download_henryhub_raw.download_eia_csv("T04.01", "EIA_T04_01_Natural_Gas_Overview_Monthly.csv")
# Out:
# Scraping Henry Hub Weekly...
# c:\Users\gefer\OneDrive - Univerzita Karlova\Natural Gas python\Final Project\Python-Final-Project-Natural-gas-price-analysis-\src\download_henryhub_raw.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if str(row[0]).strip() == "Week Of":
# Saved: henry_hub_weekly.csv
# Downloading T01.11...
# Saved: EIA_T01_11_HDD_by_CensusDivision.csv
# Downloading T01.12...
# Saved: EIA_T01_12_CDD_by_CensusDivision.csv
# Downloading T04.01...
# Saved: EIA_T04_01_Natural_Gas_Overview_Monthly.csv
# True
