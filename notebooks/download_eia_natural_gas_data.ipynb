# %%
import sys
from pathlib import Path

current_dir = Path.cwd()
sys.path.append(str(current_dir.parent))

from src import download_henryhub_raw

download_henryhub_raw.download_henryhub_html()
download_henryhub_raw.download_eia_csv("T01.11", "EIA_T01_11_HDD_by_CensusDivision.csv")
download_henryhub_raw.download_eia_csv("T01.12", "EIA_T01_12_CDD_by_CensusDivision.csv")
download_henryhub_raw.download_eia_csv("T04.01", "EIA_T04_01_Natural_Gas_Overview_Monthly.csv")
# Out:
# Project Root: C:\Users\gefer\OneDrive - Univerzita Karlova\Natural Gas python\Final Project\Python-Final-Project-Natural-gas-price-analysis-
# ...
# Success: EIA_T01_11_HDD_by_CensusDivision.csv
# ...
# Success: EIA_T01_12_CDD_by_CensusDivision.csv
# ...
# Success: EIA_T04_01_Natural_Gas_Overview_Monthly.csv
# ...
# Failed to download Henry Hub: Missing optional dependency 'xlrd'. Install xlrd >= 2.0.1 for xls Excel support Use pip or conda to install xlrd.
#    (Make sure you have 'openpyxl' installed: pip install openpyxl)
# Download process complete.
